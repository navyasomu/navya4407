# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing requried Libraries for Data Manipulation & Analysis
import pandas as pd
import numpy as np

# %%
import os                     # Importing files in operating System
os.getcwd()                   # Get Current Working Directory
os.listdir('./')              # Listing the directories in os
# Out:
# ['.config',
#  'final_output.csv',
#  'date_to_week_id_map.csv',
#  'navya_somu_B108_MiTH.csv',
#  'train_data.csv',
#  'product_prices.csv',
#  'test_data.csv',
#  'sample_data']

# %%
# Reading the CSV files


# Reading traindata
d1 = pd.read_csv('./date_to_week_id_map.csv')
d2 = pd.read_csv('./product_prices.csv')
d3 = pd.read_csv('./train_data.csv')


# Reading testdata
td1 = pd.read_csv('./date_to_week_id_map.csv')
td2 = pd.read_csv('./product_prices.csv')
td3 = pd.read_csv('./test_data.csv')

# %%
# Checking the dimensions of above files

# Train data
d1.shape,d2.shape,d3.shape
# Out:
# ((821, 2), (59000, 4), (395000, 7))

# %%
# Test data
td1.shape,td2.shape,td3.shape
# Out:
# ((821, 2), (59000, 4), (15500, 7))

# %%
# Merging the files(d1,d2) for train data

data1 = pd.merge(d1,d2,on = ['week_id'] , how = 'inner')

# Merging the files(d1,d2) for test data

tdata1 = pd.merge(td1,td2,on = ['week_id'] , how = 'inner')

# %%
data1.head()
# Out:
#          date  week_id  outlet  product_identifier  sell_price
# 0  2012-01-01       49     111                  74        2.94
# 1  2012-01-01       49     111                 337        7.44
# 2  2012-01-01       49     111                 423        0.97
# 3  2012-01-01       49     111                 432        4.97
# 4  2012-01-01       49     111                 581        4.88

# %%
tdata1.head()
# Out:
#          date  week_id  outlet  product_identifier  sell_price
# 0  2012-01-01       49     111                  74        2.94
# 1  2012-01-01       49     111                 337        7.44
# 2  2012-01-01       49     111                 423        0.97
# 3  2012-01-01       49     111                 432        4.97
# 4  2012-01-01       49     111                 581        4.88

# %%
# Merging the above data1 with d3 ---> train data

data = pd.merge(d3,data1,on = ['date','product_identifier','outlet'], how = 'inner')

# Merging the above tdata1 with td3 ---> test data

testdata = pd.merge(td3,tdata1,on = ['date','product_identifier','outlet'], how = 'inner')

# %%
# Checking Dimentions for new DataSet(data) ---> train data

data.shape
# Out:
# (395000, 9)

# %%
# Checking Dimentions for new DataSet(testdata) ---> test data

testdata.shape
# Out:
# (15500, 9)

# %%
# Summary of train data

data.describe().T
# Out:
#                           count         mean         std     min     25%  \
# product_identifier     395000.0  1509.960000  809.799518   74.00  926.00
# department_identifier  395000.0    24.460000    6.337863   11.00   21.00
# outlet                 395000.0   211.200000   91.161291  111.00  113.00
# sales                  395000.0     1.228919    3.595266    0.00    0.00
# week_id                395000.0   105.070886   32.578749   49.00   77.00
# sell_price             395000.0     4.987644    3.874444    0.05    2.68
#
#                            50%      75%      max
# product_identifier     1325.00  1753.00  3021.00
# department_identifier    22.00    31.00    33.00
# outlet                  221.50   331.00   333.00
# sales                     0.00     1.00   293.00
# week_id                 105.00   133.00   161.00
# sell_price                3.98     6.48    44.36

# %%
# Summary of test data

testdata.describe().T
# Out:
#                          count         mean          std    min      25%  \
# id                     15500.0  7750.500000  4474.608921    1.0  3875.75
# product_identifier     15500.0  1509.960000   809.824616   74.0   926.00
# department_identifier  15500.0    24.460000     6.338059   11.0    21.00
# outlet                 15500.0   211.200000    91.164117  111.0   113.00
# week_id                15500.0   163.741935     1.294390  162.0   163.00
# sell_price             15500.0     4.988229     3.879690    0.2     2.64
#
#                            50%       75%       max
# id                     7750.50  11625.25  15500.00
# product_identifier     1325.00   1753.00   3021.00
# department_identifier    22.00     31.00     33.00
# outlet                  221.50    331.00    333.00
# week_id                 164.00    165.00    166.00
# sell_price                3.97      6.68     25.97

# %%
# Printing the first 5 rows  ---> train data

data.head()
# Out:
#          date  product_identifier  department_identifier  \
# 0  2012-01-01                  74                     11
# 1  2012-01-01                 337                     11
# 2  2012-01-01                 423                     12
# 3  2012-01-01                 432                     12
# 4  2012-01-01                 581                     21
#
#           category_of_product  outlet        state  sales  week_id  sell_price
# 0                      others     111  Maharashtra      0       49        2.94
# 1                      others     111  Maharashtra      1       49        7.44
# 2                      others     111  Maharashtra      0       49        0.97
# 3                      others     111  Maharashtra      0       49        4.97
# 4  fast_moving_consumer_goods     111  Maharashtra      0       49        4.88

# %%
# Printing the first 5 rows  ---> test data

testdata.head()
# Out:
#    id        date  product_identifier  department_identifier  \
# 0   1  2014-03-01                  74                     11
# 1   2  2014-03-01                 337                     11
# 2   3  2014-03-01                 423                     12
# 3   4  2014-03-01                 432                     12
# 4   5  2014-03-01                 581                     21
#
#           category_of_product  outlet        state  week_id  sell_price
# 0                      others     111  Maharashtra      162        3.43
# 1                      others     111  Maharashtra      162        7.78
# 2                      others     111  Maharashtra      162        0.97
# 3                      others     111  Maharashtra      162        4.97
# 4  fast_moving_consumer_goods     111  Maharashtra      162        4.88

# %%
# Printing the last 5 rows ---> train data

data.tail()
# Out:
#               date  product_identifier  department_identifier  \
# 394995  2014-02-28                2932                     33
# 394996  2014-02-28                2935                     33
# 394997  2014-02-28                3004                     33
# 394998  2014-02-28                3008                     33
# 394999  2014-02-28                3021                     33
#
#        category_of_product  outlet   state  sales  week_id  sell_price
# 394995     drinks_and_food     333  Kerala      2      161        2.78
# 394996     drinks_and_food     333  Kerala      8      161        0.20
# 394997     drinks_and_food     333  Kerala      0      161        2.50
# 394998     drinks_and_food     333  Kerala      0      161        1.98
# 394999     drinks_and_food     333  Kerala      0      161        2.08

# %%
# Printing the last 5 rows ---> test data

testdata.tail()
# Out:
#           id        date  product_identifier  department_identifier  \
# 15495  15496  2014-03-31                2932                     33
# 15496  15497  2014-03-31                2935                     33
# 15497  15498  2014-03-31                3004                     33
# 15498  15499  2014-03-31                3008                     33
# 15499  15500  2014-03-31                3021                     33
#
#       category_of_product  outlet   state  week_id  sell_price
# 15495     drinks_and_food     333  Kerala      166        2.78
# 15496     drinks_and_food     333  Kerala      166        0.20
# 15497     drinks_and_food     333  Kerala      166        2.68
# 15498     drinks_and_food     333  Kerala      166        1.98
# 15499     drinks_and_food     333  Kerala      166        2.08

# %%
# Checking missing values in each columns ---> train data

data.isnull().sum()
# Out:
# date                     0
# product_identifier       0
# department_identifier    0
# category_of_product      0
# outlet                   0
# state                    0
# sales                    0
# week_id                  0
# sell_price               0
# dtype: int64

# %%
# Checking missing values in each columns ---> test data

testdata.isnull().sum()
# Out:
# id                       0
# date                     0
# product_identifier       0
# department_identifier    0
# category_of_product      0
# outlet                   0
# state                    0
# week_id                  0
# sell_price               0
# dtype: int64

# %%
# Data Types in each column ---> train data

data.dtypes
# Out:
# date                      object
# product_identifier         int64
# department_identifier      int64
# category_of_product       object
# outlet                     int64
# state                     object
# sales                      int64
# week_id                    int64
# sell_price               float64
# dtype: object

# %%
# Data Types in each column ---> test data

testdata.dtypes
# Out:
# id                         int64
# date                      object
# product_identifier         int64
# department_identifier      int64
# category_of_product       object
# outlet                     int64
# state                     object
# week_id                    int64
# sell_price               float64
# dtype: object

# %%
# Converting Objects into Category --->train data

cat_cols = ['category_of_product','state']
data[cat_cols] = data[cat_cols].astype('category')

# Converting Objects into Category --->test data

testcat_cols = ['category_of_product','state']
testdata[cat_cols] = testdata[testcat_cols].astype('category')

# %%
print(data.dtypes)
print("***********************************")
print(testdata.dtypes)
# Out:
# date                       object
# product_identifier          int64
# department_identifier       int64
# category_of_product      category
# outlet                      int64
# state                    category
# sales                       int64
# week_id                     int64
# sell_price                float64
# dtype: object
# ***********************************
# id                          int64
# date                       object
# product_identifier          int64
# department_identifier       int64
# category_of_product      category
# outlet                      int64
# state                    category
# week_id                     int64
# sell_price                float64
# dtype: object

# %%
# LabelEncoder of train data
from sklearn.preprocessing import LabelEncoder
data['state'] = LabelEncoder().fit_transform(data['state'])
data['category_of_product'] = LabelEncoder().fit_transform(data['category_of_product'])

# LabelEncoder of train data
from sklearn.preprocessing import LabelEncoder
testdata['state'] = LabelEncoder().fit_transform(testdata['state'])
testdata['category_of_product'] = LabelEncoder().fit_transform(testdata['category_of_product'])

# %%
print(data.dtypes)
print(testdata.dtypes)
# Out:
# date                      object
# product_identifier         int64
# department_identifier      int64
# category_of_product        int64
# outlet                     int64
# state                      int64
# sales                      int64
# week_id                    int64
# sell_price               float64
# dtype: object
# id                         int64
# date                      object
# product_identifier         int64
# department_identifier      int64
# category_of_product        int64
# outlet                     int64
# state                      int64
# week_id                    int64
# sell_price               float64
# dtype: object

# %%
data.head()
# Out:
#          date  product_identifier  department_identifier  category_of_product  \
# 0  2012-01-01                  74                     11                    2
# 1  2012-01-01                 337                     11                    2
# 2  2012-01-01                 423                     12                    2
# 3  2012-01-01                 432                     12                    2
# 4  2012-01-01                 581                     21                    1
#
#    outlet  state  sales  week_id  sell_price
# 0     111      1      0       49        2.94
# 1     111      1      1       49        7.44
# 2     111      1      0       49        0.97
# 3     111      1      0       49        4.97
# 4     111      1      0       49        4.88

# %%
# ----> Changing date to month format using datetime in train data
data['Month'] = pd.to_datetime(data['date']).dt.month
data
# Out:
#               date  product_identifier  department_identifier  \
# 0       2012-01-01                  74                     11
# 1       2012-01-01                 337                     11
# 2       2012-01-01                 423                     12
# 3       2012-01-01                 432                     12
# 4       2012-01-01                 581                     21
# ...            ...                 ...                    ...
# 394995  2014-02-28                2932                     33
# 394996  2014-02-28                2935                     33
# 394997  2014-02-28                3004                     33
# 394998  2014-02-28                3008                     33
# 394999  2014-02-28                3021                     33
#
#         category_of_product  outlet  state  sales  week_id  sell_price  Month
# 0                         2     111      1      0       49        2.94      1
# ...

# %%
# ----> Changing date to month format using datetime in test data
testdata['Month'] = pd.to_datetime(testdata['date']).dt.month
testdata
# Out:
#           id        date  product_identifier  department_identifier  \
# 0          1  2014-03-01                  74                     11
# 1          2  2014-03-01                 337                     11
# 2          3  2014-03-01                 423                     12
# 3          4  2014-03-01                 432                     12
# 4          5  2014-03-01                 581                     21
# ...      ...         ...                 ...                    ...
# 15495  15496  2014-03-31                2932                     33
# 15496  15497  2014-03-31                2935                     33
# 15497  15498  2014-03-31                3004                     33
# 15498  15499  2014-03-31                3008                     33
# 15499  15500  2014-03-31                3021                     33
#
#        category_of_product  outlet  state  week_id  sell_price  Month
# 0                        2     111      1      162        3.43      3
# ...

# %%
traindata = data.drop(columns = ['week_id','date'],axis = 1)              # droping columns in train data
testdata = testdata.drop(columns = ['week_id','date','id'],axis = 1)      # droping columns in test data

# %%
traindata.head()
# Out:
#    product_identifier  department_identifier  category_of_product  outlet  \
# 0                  74                     11                    2     111
# 1                 337                     11                    2     111
# 2                 423                     12                    2     111
# 3                 432                     12                    2     111
# 4                 581                     21                    1     111
#
#    state  sales  sell_price  Month
# 0      1      0        2.94      1
# 1      1      1        7.44      1
# 2      1      0        0.97      1
# 3      1      0        4.97      1
# 4      1      0        4.88      1

# %%
testdata.head()
# Out:
#    product_identifier  department_identifier  category_of_product  outlet  \
# 0                  74                     11                    2     111
# 1                 337                     11                    2     111
# 2                 423                     12                    2     111
# 3                 432                     12                    2     111
# 4                 581                     21                    1     111
#
#    state  sell_price  Month
# 0      1        3.43      3
# 1      1        7.78      3
# 2      1        0.97      3
# 3      1        4.97      3
# 4      1        4.88      3

# %%
x = traindata.drop(['sales'],axis = 1)

# %%
y = traindata['sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 100)

# %% [markdown]
# Model Building

# %%
from sklearn.neighbors import KNeighborsRegressor
def knn():
    knn = KNeighborsRegressor(n_neighbors=10)
    return knn

from sklearn.tree import ExtraTreeRegressor
def extraTreesRegressor():
    etr = ExtraTreesRegressor(n_estimators=100,max_features='auto', verbose=1, n_jobs=1)
    return etr

from sklearn.ensemble import RandomForestRegressor
def randomForestRegressor():
    clf = RandomForestRegressor(n_estimators=100,max_features='log2', verbose=1)
    return clf

def svm():
    clf = SVR(kernel='rbf', gamma='auto')
    return clf

def predict_(m,X_test):
    return pd.Series(m.predict(X_test))
def model_():
    return nn()
def model_():
    return extraTreesRegressor()
def model_():
    return svm()
def model_():
    return knn()
def model_():
    return randomForestRegressor()    

def train_(x_train,y_train):
    m = model_()
    m.fit(x_train,y_train)
    return m

def train_and_predict_(x_train,y_train,x_test):
    m = train_(x_train,y_train)
    return predict_(m, x_test), m
predicted,model = train_and_predict_(x_train,y_train,x_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   31.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.7s finished

# %%
from sklearn.metrics import r2_score
def calculate_error(test_y, predicted):
    return r2_score(test_y, predicted)

# %%
best_model = None
best_error = np.iinfo(np.int32).max

# %%
error = calculate_error(y_test,predicted)

# %%
if error < best_error:
  best_error = error
  best_model = model

# %%
print(best_error)
print(best_model)
# Out:
# 0.42135426782036045
# RandomForestRegressor(max_features='log2', verbose=1)

# %%
predicted_model = best_model.predict(testdata)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished

# %%
testdata['sales'] = predicted_model

# %%
testdata['id'] = testdata['outlet'].astype(str) + '_' +  testdata['department_identifier'].astype(str)
testdata = testdata[['id', 'sales']]

# %%
testdata.to_csv('navya_somu_B108_MiTH.csv', index=False)
